# %%
import numpy as np
def transpose_matrix(matrix):
    return np.transpose(matrix)
matrix = [
    [7, 8, 9],
    [10, 11, 12]
 ]
transposed = transpose_matrix(matrix)
print(f"Original Matrix: {matrix}")
print(f"Transposed Matrix: {transposed}")
# Out:
# Original Matrix: [[7, 8, 9], [10, 11, 12]]
# Transposed Matrix: [[ 7 10]
#  [ 8 11]
#  [ 9 12]]

# %%
def calculate_dot_product(a, b):
    dot_product = np.dot(a, b)
    return dot_product
vector_a = [1, 2, 3]
vector_b = [4, 5, 6]
dot_product = calculate_dot_product(vector_a, vector_b)
print(f"Dot Product of {vector_a} and {vector_b}: {dot_product}")

# %%
A = np.array([[1, 2], 
              [3, 4],
              [1, 1]])

B = np.array([[5, 6, 1], 
              [7, 8, 1]])
# check the matrices size before addition
try:
    # if np.shape(A) != np.shape(B):   
    #     raise ValueError("Matrices must have the same size for addition.")
    # else:
        print (np.add(A, B))
except Exception as e:
    print(e,"must be same shape")
# Out:
# operands could not be broadcast together with shapes (3,2) (2,3)
